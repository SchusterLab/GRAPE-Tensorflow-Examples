# %%
import numpy as np
import h5py
with h5py.File('/home/nelson/Simulations/GRAPE-Data/spin_chain_qft/00000_gpu_spin_chain_qft_N8.h5','r') as hf:
#         print np.array(hf.get('uks')).shape
    print np.array(hf.get('error'))
    print np.array(hf.get('error')).shape
    print np.array(hf.get('uks')).shape
    u0 = np.array(hf.get('uks'))[-1]
    print np.array(hf.get('iteration'))
    
    dressed_id = np.array(hf.get('dressed_info').get('dressed_id'))
    
with h5py.File('/home/nelson/Simulations/GRAPE-Data/spin_chain_qft/00011_gpu_spin_chain_qft_N8.h5','r') as hf:
#         print np.array(hf.get('uks')).shape
    print np.array(hf.get('error'))
    print np.array(hf.get('error')).shape
    print np.array(hf.get('uks')).shape
    u0_new = np.array(hf.get('uks'))[-1]
    
    dressed_id_new = np.array(hf.get('dressed_info').get('dressed_id'))
    
print np.allclose(u0,u0_new)

print dressed_id
print dressed_id_new
print np.allclose(dressed_id,dressed_id_new)
# Out:
# [  8.09728682e-01   9.85133410e-01   9.86354232e-01   9.85588610e-01
#    9.86762226e-01   9.74500418e-01   9.85000849e-01   9.87364411e-01
#    9.83364761e-01   9.74908412e-01   9.85756934e-01   9.57863450e-01
#    9.89377797e-01   8.96727026e-01   9.54907000e-01   9.28792953e-01
#    9.64323997e-01   9.40131366e-01   9.11029041e-01   8.60820532e-01
#    9.27277684e-01   8.88603926e-01   9.17200446e-01   8.30837250e-01
#    8.28657508e-01   7.74025798e-01   7.81852067e-01   8.13669086e-01
#    6.77432001e-01   6.16972804e-01   4.93251979e-01   5.79378009e-01
#    6.61974132e-01   4.43253398e-01   3.66447568e-01   2.66794026e-01
#    1.44465506e-01   2.81454921e-01   7.82643557e-02   9.79852676e-01
#    7.97249615e-01   1.55800104e-01   9.74487543e-01   2.56436706e-01
#    2.27044821e-02   9.78774905e-01   2.83336759e-01   9.84048307e-01
#    4.78414178e-01   9.84603047e-01   3.14582586e-01   2.56705284e-03
#    9.79741395e-01   9.07858610e-02   9.81598675e-01   5.27374864e-01
# ...

# %%
import h5py
with h5py.File('/home/nelson/Simulations/GRAPE-Data/spin_chain_qft/00084_gpu_spin_chain_qft_N2.h5','r') as hf:
#         print np.array(hf.get('uks')).shape
    print np.array(hf.get('error'))
    print np.array(hf.get('error')).shape
    print np.array(hf.get('uks')).shape
    u0 = np.array(hf.get('uks'))[-1]
    psi = np.array(hf.get('inter_vecs_mag_squared'))[-1]
    
    psi_final = np.array(hf.get('inter_vecs_mag_squared'))[-1][:,:,-1]
    
    print np.array(hf.get('inter_vecs_real')).shape
    
    psi_final_2 = np.array(hf.get('inter_vecs_raw_real'))[-1][:,:,-1] +\
    1j*np.array(hf.get('inter_vecs_raw_imag'))[-1][:,:,-1]
    
    target = np.array(hf.get('U'))
    
    
    
with h5py.File('/home/nelson/Simulations/GRAPE-Data/spin_chain_qft/00085_gpu_spin_chain_qft_N2.h5','r') as hf:
#         print np.array(hf.get('uks')).shape
    print "new"
    print np.array(hf.get('error'))
    print np.array(hf.get('error')).shape
    print np.array(hf.get('uks')).shape
    u0_new = np.array(hf.get('uks'))[-1]
    
    psi_new = np.array(hf.get('inter_vecs_mag_squared'))[-1]
    
    
    print np.array(hf)
    psi_new_final = np.array(hf.get('inter_vecs_mag_squared'))[-1][:,:,-1]
    
    psi_new_final_2 = np.array(hf.get('inter_vecs_raw_real'))[-1][:,:,-1] +\
    1j*np.array(hf.get('inter_vecs_raw_imag'))[-1][:,:,-1]
    
    
    target_new = np.array(hf.get('U'))
    
    psi_0_new = np.array(hf.get('initial_vectors_c'))
    
print np.allclose(u0,u0_new)

# print u0-u0_new

# print psi_new.shape

print np.allclose(psi,psi_new,atol=1e-3)

# print psi_final.shape
# print psi_new_final
# print psi_final
# print psi_new_final - psi_final
# print target-target_new

# print psi_final_2
# print psi_new_final_2
# print psi_final_2 - psi_new_final_2

# print psi_0_new

# print np.trace(np.dot(np.transpose(np.conjugate(psi_final_2)),psi_new_final_2))
# print np.abs(np.trace(np.dot(np.transpose(np.conjugate(np.dot(target,psi_0_new))),psi_new_final_2))/4)**2
# print np.abs(np.trace(np.dot(np.transpose(np.conjugate(np.dot(target,psi_0_new))),psi_final_2))/4)**2
# print np.abs(np.trace(np.dot(np.transpose(np.conjugate(psi_final_2)),psi_final_2))/4)**2

# print np.dot(np.transpose(np.conjugate(psi_final_2)),psi_final_2)

# print np.dot(np.transpose(np.conjugate(np.dot(target,psi_0_new))),psi_final_2)

# print np.allclose(psi_new_final_2,np.dot(target,psi_0_new),atol=1e-3)

# print np.abs(np.trace(np.dot(np.transpose(np.conjugate(np.dot(target,psi_0_new))),np.dot(target,psi_0_new)))/4)**2
# Out:
# [ 0.74324626  0.73438352  0.77433383  0.65699148  0.6689266   0.67069024
#   0.38091171  0.22433752  0.33158284  0.29191422  0.27812481  0.12498248
#   0.15904152  0.17347169  0.19384122  0.11100739  0.11367536  0.08269918
#   0.0937708   0.0736835   0.05578077  0.07260787  0.07143581  0.07225877
#   0.0297538   0.01909959  0.03441012  0.04091525  0.03742445  0.02572143
#   0.03375846  0.02272165  0.00970721  0.01091343  0.01496947  0.02005816
#   0.01548332  0.01544416  0.0119195   0.00970435  0.00969958  0.00446957
#   0.00683677  0.00793672  0.00716192  0.00467408  0.00650668  0.00698149
#   0.0034973   0.00298083  0.00242531  0.00344479  0.00272256  0.00306702
#   0.00294757  0.00261331  0.00144845  0.00156659  0.0021553   0.00115126
#   0.00123727  0.00129724  0.00119233  0.00082898  0.00082898]
# (65,)
# (65, 4, 240)
# (2, 4, 4, 241)
# new
# [ 0.00082886  0.00082886]
# (2,)
# (2, 4, 240)
# [u'H0' u'Hnames' u'Hops' u'U' u'convergence' u'dressed_info' u'error'
# ...

# %%
import h5py
with h5py.File('/home/nelson/Simulations/GRAPE-Data/transmon_pi/00161_transmon_pi.h5','r') as hf:
#         print np.array(hf.get('uks')).shape
    print np.array(hf.get('error'))
    print np.array(hf.get('error')).shape
    print np.array(hf.get('uks')).shape
    u0 = np.array(hf.get('uks'))[-1]
    psi = np.array(hf.get('inter_vecs_mag_squared'))[-1]
    
    psi_final = np.array(hf.get('inter_vecs_mag_squared'))[-1][:,:,-1]
    
    print np.array(hf.get('inter_vecs_real')).shape
    
    psi_final_2 = np.array(hf.get('inter_vecs_raw_real'))[-1][:,:,-1] +\
    1j*np.array(hf.get('inter_vecs_raw_imag'))[-1][:,:,-1]
    
    target = np.array(hf.get('U'))
    
    psi_0 = np.array(hf.get('initial_vectors_c'))
    
#     print np.abs(np.trace(np.dot(np.transpose(np.conjugate(np.dot(target,np.transpose(psi_0)))),np.transpose(psi_final_2))/4))**2
    
    print np.transpose(psi_final_2)
    
    print np.dot(target,np.transpose(psi_0))
# Out:
# [ 0.00972414  0.21810496  0.18530625  0.03701234  0.03069484  0.01890576
#   0.0086478   0.00945354  0.01187563  0.00990665  0.00919902  0.00919902]
# (12,)
# (12, 2, 800)
# (12, 2, 4, 801)
# 0.223788327437
# [[ 0.06302289-0.02495463j -0.85306209-0.5170508j ]
#  [-0.98951471+0.08632587j -0.04515268-0.05061148j]
#  [ 0.08469199+0.04175509j  0.00462883+0.0015886j ]
#  [-0.00730015+0.00359962j -0.02100652+0.00943656j]]
# [[ 0.+0.j  1.+0.j]
#  [ 1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j]]
